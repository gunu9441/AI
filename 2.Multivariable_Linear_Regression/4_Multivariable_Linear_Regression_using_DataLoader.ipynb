# %% [markdown]
# # Multivariable Linear Regression with pytorch using minibatch
# This code is all about Multivariable linear regression which is formed like a linear euqation graph using torch.nn library, torch.nn.module and minibatch.
#
# I focused on the structure of this code and try to memorize this sample code below.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %% [markdown]
# ###Data

# %%
x_train = torch.FloatTensor([[73,  80,  75], 
                               [93,  88,  93], 
                               [89,  91,  90], 
                               [96,  98,  100],   
                               [73,  66,  70]])

y_train = torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %%
dataloader = DataLoader(dataset, batch_size = 2, shuffle = True)

# %% [markdown]
# ###Model

# %%
class MultivariateLinearRegression(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3,1)
    def forward(self,x):
        return self.linear(x)

model = MultivariateLinearRegression()

# %% [markdown]
# ###Optimizer

# %%
optimizer = optim.SGD(model.parameters(),lr = 1e-5)

# %% [markdown]
# ###Training

# %%
nb_epochs = 20
for epoch in range (nb_epochs+1):
    for batch_idx, samples in enumerate(dataloader):
        print(batch_idx)
        print(samples)
        x_train, y_train = samples
        prediction = model(x_train)
        cost = F.mse_loss(prediction, y_train)

        optimizer.zero_grad()
        cost.backward()
        optimizer.step()

        print('Epoch: {:4d}/{} Batch: {}/{} Cost: {:.6f}'.format(epoch, nb_epochs, batch_idx+1,len(dataloader), cost))
# Out:
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch:    0/20 Batch: 1/3 Cost: 22896.839844
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch:    0/20 Batch: 2/3 Cost: 3206.273926
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch:    0/20 Batch: 3/3 Cost: 2141.232422
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch:    1/20 Batch: 1/3 Cost: 540.261780
# 1
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch:    1/20 Batch: 2/3 Cost: 118.776443
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch:    1/20 Batch: 3/3 Cost: 50.824787
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch:    2/20 Batch: 1/3 Cost: 12.854091
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch:    2/20 Batch: 2/3 Cost: 2.493179
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch:    2/20 Batch: 3/3 Cost: 11.826584
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch:    3/20 Batch: 1/3 Cost: 0.127645
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch:    3/20 Batch: 2/3 Cost: 0.545730
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch:    3/20 Batch: 3/3 Cost: 6.098193
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch:    4/20 Batch: 1/3 Cost: 1.450772
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch:    4/20 Batch: 2/3 Cost: 2.335818
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch:    4/20 Batch: 3/3 Cost: 0.545826
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch:    5/20 Batch: 1/3 Cost: 3.149732
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch:    5/20 Batch: 2/3 Cost: 0.168350
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch:    5/20 Batch: 3/3 Cost: 0.060240
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch:    6/20 Batch: 1/3 Cost: 0.724069
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch:    6/20 Batch: 2/3 Cost: 2.897923
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch:    6/20 Batch: 3/3 Cost: 0.002651
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch:    7/20 Batch: 1/3 Cost: 2.981172
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch:    7/20 Batch: 2/3 Cost: 0.275122
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch:    7/20 Batch: 3/3 Cost: 0.034156
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch:    8/20 Batch: 1/3 Cost: 0.009278
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch:    8/20 Batch: 2/3 Cost: 2.358477
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch:    8/20 Batch: 3/3 Cost: 2.508910
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch:    9/20 Batch: 1/3 Cost: 0.373376
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch:    9/20 Batch: 2/3 Cost: 3.433242
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch:    9/20 Batch: 3/3 Cost: 0.010753
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch:   10/20 Batch: 1/3 Cost: 0.773193
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch:   10/20 Batch: 2/3 Cost: 2.851101
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch:   10/20 Batch: 3/3 Cost: 0.004309
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch:   11/20 Batch: 1/3 Cost: 0.887114
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch:   11/20 Batch: 2/3 Cost: 0.099266
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch:   11/20 Batch: 3/3 Cost: 5.452969
# 0
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch:   12/20 Batch: 1/3 Cost: 1.043537
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch:   12/20 Batch: 2/3 Cost: 2.951494
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch:   12/20 Batch: 3/3 Cost: 0.000955
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch:   13/20 Batch: 1/3 Cost: 1.867950
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch:   13/20 Batch: 2/3 Cost: 1.958720
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch:   13/20 Batch: 3/3 Cost: 0.302168
# 0
# [tensor([[73., 80., 75.],
#         [89., 91., 90.]]), tensor([[152.],
#         [180.]])]
# Epoch:   14/20 Batch: 1/3 Cost: 2.866403
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch:   14/20 Batch: 2/3 Cost: 1.174878
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch:   14/20 Batch: 3/3 Cost: 0.185327
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch:   15/20 Batch: 1/3 Cost: 0.106993
# 1
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch:   15/20 Batch: 2/3 Cost: 2.900792
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch:   15/20 Batch: 3/3 Cost: 2.272394
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch:   16/20 Batch: 1/3 Cost: 0.180192
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch:   16/20 Batch: 2/3 Cost: 3.334413
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch:   16/20 Batch: 3/3 Cost: 0.055390
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch:   17/20 Batch: 1/3 Cost: 2.279331
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch:   17/20 Batch: 2/3 Cost: 0.532585
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch:   17/20 Batch: 3/3 Cost: 1.947229
# 0
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch:   18/20 Batch: 1/3 Cost: 0.207104
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch:   18/20 Batch: 2/3 Cost: 0.410434
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch:   18/20 Batch: 3/3 Cost: 6.607840
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch:   19/20 Batch: 1/3 Cost: 1.515007
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch:   19/20 Batch: 2/3 Cost: 2.185807
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch:   19/20 Batch: 3/3 Cost: 0.490231
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch:   20/20 Batch: 1/3 Cost: 2.693030
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch:   20/20 Batch: 2/3 Cost: 1.632793
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch:   20/20 Batch: 3/3 Cost: 0.141554
